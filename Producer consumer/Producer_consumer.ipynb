# %%
import threading
import time
import logging
import random
import queue

# Create and configure logger
logging.basicConfig(level=logging.DEBUG,
                    format='(%(threadName)-9s) %(message)s',)

BUF_SIZE = 10
q = queue.Queue(BUF_SIZE)

class ProducerThread(threading.Thread):
    def __init__(self, group=None, target=None, name=None,
                 args=(), kwargs=None, verbose=None):
        super(ProducerThread,self).__init__()
        self.target = target
        self.name = name

    def run(self):
        while True:
            if not q.full():
                item = random.randint(1,10)
                q.put(item)
                logging.debug('Putting ' + str(item)  
                              + ' : there are ' + str(q.qsize()) + ' items in queue')
                time.sleep(random.random())
            else:
                logging.debug('Cant push --> Full Queue')
        return

class ConsumerThread(threading.Thread):
    def __init__(self, group=None, target=None, name=None,
                 args=(), kwargs=None, verbose=None):
        super(ConsumerThread,self).__init__()
        self.target = target
        self.name = name
        return

    def run(self):
        while True:
            if not q.empty():
                item = q.get()
                logging.debug('Getting ' + str(item) 
                              + ' : there are ' + str(q.qsize()) + ' items in queue')
                time.sleep(random.random())
            else:
                logging.debug('Cant pop --> Empty Queue')
        return

if __name__ == '__main__':
    
    p = ProducerThread(name='producer')
    c = ConsumerThread(name='consumer')

    p.start()
    time.sleep(2)
    c.start()
    #time.sleep(2)
# Out:
# (producer ) Putting 3 : there are 1 items in queue
# (producer ) Putting 6 : there are 2 items in queue
# (producer ) Putting 2 : there are 3 items in queue
# (producer ) Putting 7 : there are 4 items in queue
# (producer ) Putting 4 : there are 5 items in queue
# (producer ) Putting 1 : there are 6 items in queue
# (producer ) Putting 10 : there are 7 items in queue
# (consumer ) Getting 3 : there are 6 items in queue
# (producer ) Putting 9 : there are 7 items in queue
# (consumer ) Getting 6 : there are 6 items in queue
# (consumer ) Getting 2 : there are 5 items in queue
# (producer ) Putting 7 : there are 6 items in queue
# (consumer ) Getting 7 : there are 5 items in queue
# (producer ) Putting 2 : there are 6 items in queue
# (consumer ) Getting 4 : there are 5 items in queue
# (consumer ) Getting 1 : there are 4 items in queue
# (producer ) Putting 10 : there are 5 items in queue
# (producer ) Putting 3 : there are 6 items in queue
# (consumer ) Getting 10 : there are 5 items in queue
# (producer ) Putting 8 : there are 6 items in queue
# (producer ) Putting 6 : there are 7 items in queue
# (producer ) Putting 9 : there are 8 items in queue
# (consumer ) Getting 9 : there are 7 items in queue
# (producer ) Putting 10 : there are 8 items in queue
# (consumer ) Getting 7 : there are 7 items in queue
# (producer ) Putting 3 : there are 8 items in queue
# (consumer ) Getting 2 : there are 7 items in queue
# (producer ) Putting 7 : there are 8 items in queue
# (producer ) Putting 4 : there are 9 items in queue
# (consumer ) Getting 10 : there are 8 items in queue
# (producer ) Putting 6 : there are 9 items in queue
# (consumer ) Getting 3 : there are 8 items in queue
# (producer ) Putting 3 : there are 9 items in queue
# (consumer ) Getting 8 : there are 8 items in queue
# (producer ) Putting 10 : there are 9 items in queue
# (consumer ) Getting 6 : there are 8 items in queue
# (consumer ) Getting 9 : there are 7 items in queue
# (producer ) Putting 4 : there are 8 items in queue
# (producer ) Putting 3 : there are 9 items in queue
# (consumer ) Getting 10 : there are 8 items in queue
# (consumer ) Getting 3 : there are 7 items in queue
# (producer ) Putting 7 : there are 8 items in queue
# (consumer ) Getting 7 : there are 7 items in queue
# (producer ) Putting 8 : there are 8 items in queue
# (consumer ) Getting 4 : there are 7 items in queue
# (consumer ) Getting 6 : there are 6 items in queue
# (producer ) Putting 3 : there are 7 items in queue
# (consumer ) Getting 3 : there are 6 items in queue
# (producer ) Putting 7 : there are 7 items in queue
# (consumer ) Getting 10 : there are 6 items in queue
# (producer ) Putting 4 : there are 7 items in queue
# (consumer ) Getting 4 : there are 6 items in queue
# (producer ) Putting 6 : there are 7 items in queue
# (producer ) Putting 5 : there are 8 items in queue
# (consumer ) Getting 3 : there are 7 items in queue
# (producer ) Putting 2 : there are 8 items in queue
# (consumer ) Getting 7 : there are 7 items in queue
# (consumer ) Getting 8 : there are 6 items in queue
# (producer ) Putting 7 : there are 7 items in queue
# (consumer ) Getting 3 : there are 6 items in queue
# (consumer ) Getting 7 : there are 5 items in queue
# (producer ) Putting 10 : there are 6 items in queue
# (consumer ) Getting 4 : there are 5 items in queue
# (producer ) Putting 2 : there are 6 items in queue
# (consumer ) Getting 6 : there are 5 items in queue
# (consumer ) Getting 5 : there are 4 items in queue
# (producer ) Putting 4 : there are 5 items in queue
# (consumer ) Getting 2 : there are 4 items in queue
# (producer ) Putting 4 : there are 5 items in queue
# (consumer ) Getting 7 : there are 4 items in queue
# (producer ) Putting 4 : there are 5 items in queue
# (producer ) Putting 7 : there are 6 items in queue
# (consumer ) Getting 10 : there are 5 items in queue
# (producer ) Putting 8 : there are 6 items in queue
# (consumer ) Getting 2 : there are 5 items in queue
# (producer ) Putting 9 : there are 6 items in queue
# (consumer ) Getting 4 : there are 5 items in queue
# (producer ) Putting 4 : there are 6 items in queue
# (producer ) Putting 2 : there are 7 items in queue
# (producer ) Putting 7 : there are 8 items in queue
# (consumer ) Getting 4 : there are 7 items in queue
# (consumer ) Getting 4 : there are 6 items in queue
# (producer ) Putting 1 : there are 7 items in queue
# (producer ) Putting 1 : there are 8 items in queue
# (producer ) Putting 1 : there are 9 items in queue
# (consumer ) Getting 7 : there are 8 items in queue
# (consumer ) Getting 8 : there are 7 items in queue
# (producer ) Putting 6 : there are 8 items in queue
# (consumer ) Getting 9 : there are 7 items in queue
# (producer ) Putting 1 : there are 8 items in queue
# (consumer ) Getting 4 : there are 7 items in queue
# (consumer ) Getting 2 : there are 6 items in queue
# (producer ) Putting 10 : there are 7 items in queue
# (consumer ) Getting 7 : there are 6 items in queue
# (producer ) Putting 2 : there are 7 items in queue
# (consumer ) Getting 1 : there are 6 items in queue
# (producer ) Putting 3 : there are 7 items in queue
# (consumer ) Getting 1 : there are 6 items in queue
# (consumer ) Getting 1 : there are 5 items in queue
# (producer ) Putting 5 : there are 6 items in queue
# (consumer ) Getting 6 : there are 5 items in queue
# (producer ) Putting 7 : there are 6 items in queue
# (consumer ) Getting 1 : there are 5 items in queue
# (producer ) Putting 9 : there are 6 items in queue
# (consumer ) Getting 10 : there are 5 items in queue
# (consumer ) Getting 2 : there are 4 items in queue
# (producer ) Putting 8 : there are 5 items in queue
# (consumer ) Getting 3 : there are 4 items in queue
# (producer ) Putting 7 : there are 5 items in queue
# (producer ) Putting 7 : there are 6 items in queue
# (consumer ) Getting 5 : there are 5 items in queue
# (producer ) Putting 3 : there are 6 items in queue
# (consumer ) Getting 7 : there are 5 items in queue
# (producer ) Putting 8 : there are 6 items in queue
# (consumer ) Getting 9 : there are 5 items in queue
# (consumer ) Getting 8 : there are 4 items in queue
# (producer ) Putting 5 : there are 5 items in queue
# (producer ) Putting 5 : there are 6 items in queue
# (consumer ) Getting 7 : there are 5 items in queue
# (producer ) Putting 9 : there are 6 items in queue
# (producer ) Putting 8 : there are 7 items in queue
# (producer ) Putting 9 : there are 8 items in queue
# (consumer ) Getting 7 : there are 7 items in queue
# (producer ) Putting 9 : there are 8 items in queue
# (consumer ) Getting 3 : there are 7 items in queue
# (consumer ) Getting 8 : there are 6 items in queue
# (producer ) Putting 10 : there are 7 items in queue
# (producer ) Putting 4 : there are 8 items in queue
# (consumer ) Getting 5 : there are 7 items in queue
# (consumer ) Getting 5 : there are 6 items in queue
# (producer ) Putting 1 : there are 7 items in queue
# (producer ) Putting 6 : there are 8 items in queue
# (consumer ) Getting 9 : there are 7 items in queue
# (consumer ) Getting 8 : there are 6 items in queue
# (producer ) Putting 3 : there are 7 items in queue
# (consumer ) Getting 9 : there are 6 items in queue
# (consumer ) Getting 9 : there are 5 items in queue
# (consumer ) Getting 10 : there are 4 items in queue
# (producer ) Putting 8 : there are 5 items in queue
# (consumer ) Getting 4 : there are 4 items in queue
# (producer ) Putting 9 : there are 5 items in queue
# (consumer ) Getting 1 : there are 4 items in queue
# (producer ) Putting 3 : there are 5 items in queue
# (producer ) Putting 3 : there are 6 items in queue
# (consumer ) Getting 6 : there are 5 items in queue
# (producer ) Putting 3 : there are 6 items in queue
# (consumer ) Getting 3 : there are 5 items in queue
# (producer ) Putting 8 : there are 6 items in queue
# (consumer ) Getting 8 : there are 5 items in queue
# (producer ) Putting 1 : there are 6 items in queue
# (producer ) Putting 7 : there are 7 items in queue
# (consumer ) Getting 9 : there are 6 items in queue
# (producer ) Putting 3 : there are 7 items in queue
# (producer ) Putting 8 : there are 8 items in queue
# (producer ) Putting 1 : there are 9 items in queue
# (consumer ) Getting 3 : there are 8 items in queue
# (consumer ) Getting 3 : there are 7 items in queue
# (producer ) Putting 7 : there are 8 items in queue
# (consumer ) Getting 3 : there are 7 items in queue
# (producer ) Putting 7 : there are 8 items in queue
# (consumer ) Getting 8 : there are 7 items in queue
# (consumer ) Getting 1 : there are 6 items in queue
# (producer ) Putting 4 : there are 7 items in queue
# (producer ) Putting 8 : there are 8 items in queue
# (consumer ) Getting 7 : there are 7 items in queue
# (consumer ) Getting 3 : there are 6 items in queue
# (consumer ) Getting 8 : there are 5 items in queue
# (consumer ) Getting 1 : there are 4 items in queue
# (producer ) Putting 10 : there are 5 items in queue
# (producer ) Putting 9 : there are 6 items in queue
# (producer ) Putting 6 : there are 7 items in queue
# (consumer ) Getting 7 : there are 6 items in queue
# (producer ) Putting 1 : there are 7 items in queue
# (producer ) Putting 3 : there are 8 items in queue
# (consumer ) Getting 7 : there are 7 items in queue
# (producer ) Putting 8 : there are 8 items in queue
# (producer ) Putting 2 : there are 9 items in queue
# (producer ) Putting 3 : there are 10 items in queue
# (consumer ) Getting 4 : there are 9 items in queue
# (producer ) Putting 5 : there are 10 items in queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (consumer ) Getting 8 : there are 9 items in queue
# (producer ) Putting 5 : there are 10 items in queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (consumer ) Getting 10 : there are 9 items in queue
# (producer ) Putting 5 : there are 10 items in queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# (producer ) Cant push --> Full Queue
# ...
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (producer ) Putting 2 : there are 1 items in queue
# (consumer ) Getting 2 : there are 0 items in queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# (consumer ) Cant pop --> Empty Queue
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# (producer ) Putting 4 : there are 2 items in queue
# (producer ) Putting 10 : there are 3 items in queue
# (consumer ) Getting 9 : there are 2 items in queue
# (consumer ) Getting 4 : there are 1 items in queue
# (producer ) Putting 5 : there are 2 items in queue
# (consumer ) Getting 10 : there are 1 items in queue
# (consumer ) Getting 5 : there are 0 items in queue
# (producer ) Putting 2 : there are 1 items in queue
# (consumer ) Getting 2 : there are 0 items in queue
# (producer ) Putting 2 : there are 1 items in queue
# (consumer ) Getting 2 : there are 0 items in queue
# (producer ) Putting 1 : there are 1 items in queue
# (consumer ) Getting 1 : there are 0 items in queue
# (producer ) Putting 2 : there are 1 items in queue
# (producer ) Putting 1 : there are 2 items in queue
